# %% [markdown]
# <a href="https://colab.research.google.com/github/MainN/diploma/blob/master/Pystan_measles_m%3D1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install pystan
# !pip install stan_utility
# !pip install arviz
# Out:
# Requirement already satisfied: pystan in /usr/local/lib/python3.7/dist-packages (2.19.1.1)
# Requirement already satisfied: numpy>=1.7 in /usr/local/lib/python3.7/dist-packages (from pystan) (1.19.5)
# Requirement already satisfied: Cython!=0.25.1,>=0.22 in /usr/local/lib/python3.7/dist-packages (from pystan) (0.29.22)
# Requirement already satisfied: stan_utility in /usr/local/lib/python3.7/dist-packages (0.1.2)
# Requirement already satisfied: scipy in /usr/local/lib/python3.7/dist-packages (from stan_utility) (1.4.1)
# Requirement already satisfied: h5py in /usr/local/lib/python3.7/dist-packages (from stan_utility) (2.10.0)
# Requirement already satisfied: pystan in /usr/local/lib/python3.7/dist-packages (from stan_utility) (2.19.1.1)
# Requirement already satisfied: numpy in /usr/local/lib/python3.7/dist-packages (from stan_utility) (1.19.5)
# Requirement already satisfied: pandas in /usr/local/lib/python3.7/dist-packages (from stan_utility) (1.1.5)
# Requirement already satisfied: six in /usr/local/lib/python3.7/dist-packages (from h5py->stan_utility) (1.15.0)
# Requirement already satisfied: Cython!=0.25.1,>=0.22 in /usr/local/lib/python3.7/dist-packages (from pystan->stan_utility) (0.29.22)
# Requirement already satisfied: pytz>=2017.2 in /usr/local/lib/python3.7/dist-packages (from pandas->stan_utility) (2018.9)
# Requirement already satisfied: python-dateutil>=2.7.3 in /usr/local/lib/python3.7/dist-packages (from pandas->stan_utility) (2.8.1)
# Collecting arviz
#   Downloading https://files.pythonhosted.org/packages/e2/a8/e2ad120b06822e29e0d185bed1ae300576f3f61f97fceb6933ba6f6accf7/arviz-0.11.2-py3-none-any.whl (1.6MB)
#      |████████████████████████████████| 1.6MB 4.0MB/s
# Requirement already satisfied: scipy>=0.19 in /usr/local/lib/python3.7/dist-packages (from arviz) (1.4.1)
# Requirement already satisfied: pandas>=0.23 in /usr/local/lib/python3.7/dist-packages (from arviz) (1.1.5)
# Requirement already satisfied: setuptools>=38.4 in /usr/local/lib/python3.7/dist-packages (from arviz) (54.2.0)
# Requirement already satisfied: typing-extensions<4,>=3.7.4.3 in /usr/local/lib/python3.7/dist-packages (from arviz) (3.7.4.3)
# Requirement already satisfied: numpy>=1.12 in /usr/local/lib/python3.7/dist-packages (from arviz) (1.19.5)
# Requirement already satisfied: packaging in /usr/local/lib/python3.7/dist-packages (from arviz) (20.9)
# Collecting netcdf4
#   Downloading https://files.pythonhosted.org/packages/37/56/f65978898fb8e7e5df9c67531d86eb24eb04938deae3b61dbcce12c98212/netCDF4-1.5.6-cp37-cp37m-manylinux2014_x86_64.whl (4.7MB)
#      |████████████████████████████████| 4.7MB 20.1MB/s
# Collecting xarray>=0.16.1
#   Downloading https://files.pythonhosted.org/packages/a5/19/debc1f470b8b9e2949da221663c8102ed6728f4d38dc964085ca43de1428/xarray-0.17.0-py3-none-any.whl (759kB)
#      |████████████████████████████████| 768kB 51.1MB/s
# Requirement already satisfied: matplotlib>=3.0 in /usr/local/lib/python3.7/dist-packages (from arviz) (3.2.2)
# Requirement already satisfied: pytz>=2017.2 in /usr/local/lib/python3.7/dist-packages (from pandas>=0.23->arviz) (2018.9)
# Requirement already satisfied: python-dateutil>=2.7.3 in /usr/local/lib/python3.7/dist-packages (from pandas>=0.23->arviz) (2.8.1)
# Requirement already satisfied: pyparsing>=2.0.2 in /usr/local/lib/python3.7/dist-packages (from packaging->arviz) (2.4.7)
# Collecting cftime
#   Downloading https://files.pythonhosted.org/packages/41/e0/3e120cca16571c5ee3b35f1ed432c2aae5dc91e2b789e8b9c3a70e721ea0/cftime-1.4.1-cp37-cp37m-manylinux2014_x86_64.whl (313kB)
#      |████████████████████████████████| 317kB 48.4MB/s
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.7/dist-packages (from matplotlib>=3.0->arviz) (1.3.1)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.7/dist-packages (from matplotlib>=3.0->arviz) (0.10.0)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.7/dist-packages (from python-dateutil>=2.7.3->pandas>=0.23->arviz) (1.15.0)
# Installing collected packages: cftime, netcdf4, xarray, arviz
#   Found existing installation: xarray 0.15.1
#     Uninstalling xarray-0.15.1:
#       Successfully uninstalled xarray-0.15.1
# Successfully installed arviz-0.11.2 cftime-1.4.1 netcdf4-1.5.6 xarray-0.17.0

# %%
import os
import pystan
import seaborn as sns
import pandas as pd
from math import exp, cos, pi, log
import stan_utility
import numpy as np
import arviz

# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Drive already mounted at /content/gdrive; to attempt to forcibly remount, call drive.mount("/content/gdrive", force_remount=True).

# %%
My_data=pd.read_csv("/content/gdrive/My Drive/data.csv")
My_data=My_data.fillna(0)
My_data
# Out:
#         t5     t6     t9   t12   t15   t20
# 0    386.0  249.0  108.0  66.0  67.0  59.0
# 1    281.0  229.0   39.0  38.0   0.0  18.0
# 2      0.0  115.0    0.0   0.0   0.0  28.0
# 3    122.0    0.0  105.0  21.0  34.0  32.0
# 4    868.0  482.0  370.0   0.0  98.0  72.0
# ..     ...    ...    ...   ...   ...   ...
# 159  463.0  254.0    0.0  97.0   0.0  47.0
# 160  478.0   93.0    0.0  38.0  23.0  20.0
# 161    0.0  402.0    0.0   0.0  26.0  20.0
# 162  159.0  100.0   48.0  31.0  14.0  12.0
# 163  121.0   60.0    0.0  41.0  13.0   7.0
#
# [164 rows x 6 columns]

# %%
code ='''
data {
    int  T ;  // Time
    int  N ;  // number of individuals
    real time[T]; // time measurements
    real dset[N,T]; // data
    
 }
parameters {
    real b0;
    real b1;
    vector[N] C;
    real<lower = 0> delta_C;
    real<lower = 0> delta_ERR;
}
model {
    delta_ERR ~ exponential(1);
    delta_C ~ exponential(1);
    b0 ~ normal(0,1);
    b1 ~ normal(0,1);
    C ~ normal(0,delta_C);
    for (t in 1:T) {
        for (i in 1:N) {
            if (dset[i,t] != 0)  {dset[i,t] ~ normal(C[i] + b0 + b1 * time[t],delta_ERR);}
        }
    }
}
'''
sm = pystan.StanModel(model_code=code)
# Out:
# INFO:pystan:COMPILING THE C++ CODE FOR MODEL anon_model_fe15037ebbe0e7dfad1b1a69aea68d55 NOW.

# %%
T=1#6
time =[log(x) for x in [1]]#[log(x) for x in [1,2,5,8,11,16]]
N = len(My_data)
h=My_data.values[:,1]

h=h.reshape((164,1))
print(h.shape)
data  = dict(
        T=T,
        N=N,
        dset=h,
        time=time)
init = dict(
    b0 = 6,
    b1 = -2,
    C = [0]*N,
    delta_C=1,
    delta_ERR=1)
# Out:
# (164, 1)

# %%
fit = sm.sampling(data=data, iter=10000, chains=4, init=[init]*4,thin=1,control={'max_treedepth': 20})
op = fit.extract()
# Out:
# WARNING:pystan:Chain 1: E-BFMI = 0.00678
# WARNING:pystan:Chain 2: E-BFMI = 0.0149
# WARNING:pystan:Chain 3: E-BFMI = 0.00963
# WARNING:pystan:Chain 4: E-BFMI = 0.0089
# WARNING:pystan:E-BFMI below 0.2 indicates you may need to reparameterize your model

# %%
print(fit)
# Out:
# Inference for Stan model: anon_model_fe15037ebbe0e7dfad1b1a69aea68d55.
# 4 chains, each with iter=10000; warmup=5000; thin=1;
# post-warmup draws per chain=5000, total post-warmup draws=20000.
#
#              mean se_mean     sd   2.5%    25%     50%    75%  97.5%  n_eff   Rhat
# b0            0.7    0.02   1.01  -1.27   0.02     0.7   1.38   2.65   3204    1.0
# b1           0.04    0.02   1.01  -1.97  -0.65    0.05   0.74   1.96   2935    1.0
# C[1]         0.02  6.2e-3   1.14  -2.39  -0.37  1.5e-4   0.38   2.51  34422    1.0
# C[2]       5.5e-3  5.9e-3   1.15   -2.4  -0.37  3.7e-3   0.37   2.42  38489    1.0
# C[3]         0.02  6.2e-3   1.17  -2.43  -0.36  4.2e-3   0.39   2.44  35392    1.0
# C[4]       8.2e-4  6.4e-3   1.15  -2.42  -0.38  2.6e-3   0.37   2.45  32753    1.0
# C[5]         0.03  6.3e-3   1.18  -2.44  -0.37  7.4e-3   0.39   2.53  35222    1.0
# C[6]       8.1e-3  5.8e-3   1.11  -2.33  -0.36  3.5e-3   0.37    2.4  36002    1.0
# C[7]      -4.2e-4  5.5e-3   1.12  -2.34  -0.36  2.2e-3   0.36   2.36  42010    1.0
# C[8]       6.7e-3  6.6e-3   1.18  -2.41  -0.37 -2.8e-3   0.38   2.51  32080    1.0
# C[146]     9.5e-4  6.1e-3   1.16  -2.39  -0.38 -1.8e-3   0.36   2.45  35531    1.0
# C[147]       0.03  5.9e-3   1.15  -2.31  -0.35  7.8e-3   0.39   2.56  38822    1.0
# C[148]    -3.5e-3  5.6e-3   1.16  -2.45  -0.38  8.5e-4   0.37   2.45  43175    1.0
# C[149]    -6.1e-3  6.1e-3   1.17  -2.44  -0.38  8.6e-5   0.37   2.42  36929    1.0
# C[150]       0.02  6.1e-3   1.18  -2.29  -0.37    0.01   0.39   2.38  37234    1.0
# C[151]    -8.6e-3  6.3e-3   1.14  -2.44  -0.36 -1.5e-3   0.37   2.33  32359    1.0
# C[152]     1.9e-3  6.0e-3   1.17  -2.45  -0.38 -1.9e-3   0.38   2.52  38149    1.0
# C[153]    -3.7e-3  6.0e-3   1.18  -2.46  -0.38  2.7e-3   0.37   2.44  38483    1.0
# C[154]    -4.1e-4  6.2e-3   1.16  -2.47  -0.37  1.5e-3   0.36   2.42  35294    1.0
# C[155]     2.8e-3  5.8e-3   1.13  -2.41  -0.37  4.6e-3   0.38   2.36  37820    1.0
# C[156]    -7.7e-3  6.2e-3    1.2  -2.46  -0.39 -4.4e-3   0.37   2.39  37197    1.0
# C[157]     5.7e-3  6.0e-3   1.21  -2.41  -0.37  4.4e-3   0.38   2.48  40503    1.0
# C[158]     9.5e-3  5.8e-3   1.11  -2.39  -0.36  3.3e-3   0.37   2.41  36498    1.0
# C[159]    -5.0e-3  6.0e-3   1.14  -2.41  -0.38 -2.1e-3   0.37   2.34  36752    1.0
# C[160]       0.02  6.4e-3   1.18  -2.46  -0.36  6.6e-3   0.37   2.57  34228    1.0
# C[161]    -3.9e-3  6.7e-3   1.17  -2.49  -0.36  3.8e-3   0.35   2.44  30417    1.0
# C[162]       0.02  6.4e-3   1.15  -2.33  -0.36  7.3e-3   0.38   2.55  31853    1.0
# C[163]     1.1e-3  6.8e-3   1.18  -2.47  -0.37 -5.6e-4   0.37   2.51  30047    1.0
# C[164]     3.7e-3  6.0e-3   1.15  -2.37  -0.37 -2.2e-3   0.37   2.42  36310    1.0
# delta_C      0.87    0.09   0.77   0.13   0.34    0.62   1.12   2.96     77   1.03
# delta_ERR  161.37     0.1   6.17 149.88 157.22  161.23 165.33 174.25   3942    1.0
# lp__       -794.8   16.87 137.01  -1052 -892.2  -796.5 -695.7 -543.1     66   1.04
#
# Samples were drawn using NUTS at Mon Apr 19 13:06:27 2021.
# For each parameter, n_eff is a crude measure of effective sample size,
# and Rhat is the potential scale reduction factor on split chains (at
# convergence, Rhat=1).

# %%
print(op.keys())
print(len(op['b0']))
# Out:
# odict_keys(['b0', 'b1', 'C', 'delta_C', 'delta_ERR', 'lp__'])
# 20000

# %%
arviz.plot_trace(fit)
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x7fb97c79ecd0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fb96488e690>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x7fb964847f10>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fb96481fc10>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x7fb9647c2e50>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fb964f0ce50>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x7fb963907a90>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fb9638df910>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x7fb9638265d0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fb9637f3b50>]],
#       dtype=object)

# %%
fit.plot('delta_ERR');
# Out:
# WARNING:pystan:Deprecation warning. PyStan plotting deprecated, use ArviZ library (Python 3.5+). `pip install arviz`; `arviz.plot_trace(fit)`)

# %%
fit.plot('b0');
# Out:
# WARNING:pystan:Deprecation warning. PyStan plotting deprecated, use ArviZ library (Python 3.5+). `pip install arviz`; `arviz.plot_trace(fit)`)

# %%
fit.plot('b1');
# Out:
# WARNING:pystan:Deprecation warning. PyStan plotting deprecated, use ArviZ library (Python 3.5+). `pip install arviz`; `arviz.plot_trace(fit)`)

# %%
fit.plot('delta_C');
# Out:
# WARNING:pystan:Deprecation warning. PyStan plotting deprecated, use ArviZ library (Python 3.5+). `pip install arviz`; `arviz.plot_trace(fit)`)

# %%
fit.plot('C');
# Out:
# WARNING:pystan:Deprecation warning. PyStan plotting deprecated, use ArviZ library (Python 3.5+). `pip install arviz`; `arviz.plot_trace(fit)`)
